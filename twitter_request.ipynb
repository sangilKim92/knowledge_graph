# %%
from twitter_scraper import get_trends, get_tweets

# %%
bearer_token = "AAAAAAAAAAAAAAAAAAAAAABHMwEAAAAA6FQjDcRr3NNzVzfLZN5MtYFiygQ%3DJQPCVWFEOBepCotJiUqBTLcvmGPONWMY4pOdwgs840QwwByVto"

api_secret_key ="KDU573HAwpNgzWeJfKUkpWgzVpSGJIOHSCF85opEdPaV2thzHe"

api_key = "9IWffmWTQ33Q5C5Wa98tVNvDI"

access_token = "1350052599093882882-JZNUnnqVgzUSsbSwoXBmBY9LhXo6Uk"

access_token_secret = "GIzLxc4Lu08kQ1TuwEWZ9O6OKPHwMiehQpBwHuVJVEeiE"

# %%
result = []

# %%
import requests
import os
import json

# To set your environment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'


def auth():
    return os.environ.get("BEARER_TOKEN")


def create_url():
    # Replace with user ID below
    user_id = "335141638"
    return "https://api.twitter.com/2/users/{}/tweets".format(user_id)


def get_params():
    # Tweet fields are adjustable.
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld
    return {"tweet.fields": "created_at,author_id"}


def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


def connect_to_endpoint(url, headers, params):
    response = requests.request("GET", url, headers=headers, params=params)
    
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()


def main():
    #bearer_token = auth()
    url = create_url()
    headers = create_headers(bearer_token)
    params = get_params()
    json_response = connect_to_endpoint(url, headers, params)
    print(json.dumps(json_response, indent=4, sort_keys=True))
    print(type(json.dumps(json_response, indent=4, sort_keys=True)))


if __name__ == "__main__":
    main()
# Out:
# {
#     "data": [
#         {
#             "author_id": "335141638",
#             "created_at": "2021-02-23T06:41:31.000Z",
#             "id": "1364103074860556290",
#             "text": "\ud83c\udf32\ud83c\udf33\ud83c\udf41\ud83c\udf42 https://t.co/TmQvpUKPaj"
#         },
#         {
#             "author_id": "335141638",
#             "created_at": "2021-02-21T16:09:38.000Z",
#             "id": "1363521271946911745",
#             "text": "#JIMIN https://t.co/9OxY9EVPvo"
#         },
#         {
#             "author_id": "335141638",
#             "created_at": "2021-02-18T16:51:49.000Z",
#             "id": "1362444723789570054",
#             "text": "\uac70\uc9d3\ub9d0 \ud558\uc9c0\ub9c8..\uc0ac\ub78c\uc758 \ubc94\uc8fc\ub97c \ub118\uc5b4\uc130\uad6c\ub098\n#JIMIN"
#         },
#         {
#             "author_id": "335141638",
#             "created_at": "2021-02-18T15:16:29.000Z",
#             "id": "1362420731330523136",
# ...

# %%
import requests
import os
import json

# To set your enviornment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'


def auth():
    return os.environ.get("BEARER_TOKEN")


def create_url():
    tweet_fields = "tweet.fields=lang,author_id,id"
    # Tweet fields are adjustable.
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld
    ids = "ids=1278747501642657792,1255542774432063488"
    # You can adjust ids to include a single Tweets.
    # Or you can add to up to 100 comma-separated IDs
    url = "https://api.twitter.com/2/tweets?{}&{}".format(ids, tweet_fields)
    return url


def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


def connect_to_endpoint(url, headers):
    response = requests.request("GET", url, headers=headers)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()


def main():
    #bearer_token = auth()
    url = create_url()
    headers = create_headers(bearer_token)
    json_response = connect_to_endpoint(url, headers)
    print(json.dumps(json_response, indent=4, sort_keys=True))


if __name__ == "__main__":
    main()
# Out:
# 200
# {
#     "data": [
#         {
#             "author_id": "2244994945",
#             "id": "1278747501642657792",
#             "lang": "en",
#             "text": "It's been a year since Twitter's Developer Labs launched.\n\nAs we build towards the next generation of the #TwitterAPI (coming VERY soon), see what we've learned and changed along the way. https://t.co/WvjuEWCa6G"
#         },
#         {
#             "author_id": "2244994945",
#             "id": "1255542774432063488",
#             "lang": "en",
#             "text": "During these unprecedented times, what\u2019s happening on Twitter can help the world better understand &amp; respond to the pandemic. \n\nWe're launching a free COVID-19 stream endpoint so qualified devs &amp; researchers can study the public conversation in real-time. https://t.co/BPqMcQzhId"
#         }
#     ]
# }

# %%
import requests
import os
import json

# To set your enviornment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'


def auth():
    return os.environ.get("BEARER_TOKEN")


def create_url(query):
    query="#음식"
    # Tweet fields are adjustable.
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld
    tweet_fields = "tweet.fields=author_id"
    user_fields = "user.fields=id,name"
    url = "https://api.twitter.com/2/tweets/search/recent?query={}&{}&{}&max_results={}".format(
        query, user_fields,tweet_fields, 10
    )
    return url


def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


def connect_to_endpoint(url, headers):
    response = requests.request("GET", url, headers=headers)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()


def main():
    #bearer_token = auth()
    query = ['피씨방','초밥','짜장면','사진','아메리카노','카페','운동','순대국','데이트','피자','한식','일식','중식','햄버거','우유','고기'\
             ,'삼겹살','제육볶음','된장찌개','김치찌개','라면','김밥','비빔밥','오리구이','연어','장어','물','산책','게임','보드게임','동물'\
             ,'치킨','돈까스','고등어','해산물','탕수육','짬뽕','카레','공방','체험','채소','노래방','술','소주','맥주']
    url = create_url("#음식")
    headers = create_headers(bearer_token)
    json_response = connect_to_endpoint(url, headers)
    result = json.dumps(json_response, indent=4, sort_keys=True,ensure_ascii=False)
    print(result)



if __name__ == "__main__":
    main()
# Out:
# 400
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-66-f0236bf6bcd3> in <module>
#      55
#      56 if __name__ == "__main__":
# ---> 57     main()
#
# <ipython-input-66-f0236bf6bcd3> in main()
#      48     url = create_url("#음식")
#      49     headers = create_headers(bearer_token)
# ---> 50     json_response = connect_to_endpoint(url, headers)
#      51     result = json.dumps(json_response, indent=4, sort_keys=True,ensure_ascii=False)
#      52     print(result)
#
# <ipython-input-66-f0236bf6bcd3> in connect_to_endpoint(url, headers)
#      37     print(response.status_code)
#      38     if response.status_code != 200:
# ---> 39         raise Exception(response.status_code, response.text)
#      40     return response.json()
#      41
#
# ...

# %%
import requests
import os
import json

# To set your enviornment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'


def auth():
    return os.environ.get("BEARER_TOKEN")


def create_url():
    query = "음식"
    # Tweet fields are adjustable.
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld
    tweet_fields = "tweet.fields=author_id"
    
    url = "https://api.twitter.com/2/tweets/search/recent?query={}&{}&max_results={}".format(
        query,tweet_fields, 10
    )
    return url


def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


def connect_to_endpoint(url, headers):
    response = requests.request("GET", url, headers=headers)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(response.status_code, response.text)
    return response.json()


def main():
    #bearer_token = auth()
    url = create_url()
    headers = create_headers(bearer_token)
    json_response = connect_to_endpoint(url, headers)
    result = json.dumps(json_response, indent=4, sort_keys=True,ensure_ascii=False)
    print(result)



if __name__ == "__main__":
    main()
# Out:
# 200
# {
#     "data": [
#         {
#             "author_id": "1350123789430898696",
#             "id": "1364142485799202819",
#             "text": "RT @ENHYPEN_members: 저는 오늘 점심은 화끈한 매운맛 불♡볶음면을 먹었어요ㅎㅎ아 그리고 저는 매운음식을 좋아하고 잘먹고 신맛도 좋아해서 신걸 잘먹습니당 그리고 단것도 좋아하구 짠것도 좋아하고 그냥 다 좋아합니다 ㅎㅎ 먹는걸 딱히 가리…"
#         },
#         {
#             "author_id": "1358440748769628161",
#             "id": "1364142476282318850",
#             "text": "@PY_CyAl …제가 먹는 음식엔 이름 붙이지 말아주세요!"
#         },
#         {
#             "author_id": "1363081651828350976",
#             "id": "1364142457756160001",
#             "text": "쿠팡이츠 - 맛있는 음식을 빠르고 편하게\n앱 설치 후 [쿠폰 받기]를 누르면 5,000원 쿠폰 2매 지급!\n\n앱 설치하기: https://t.co/Og9zHEUepC\n10,000원 쿠폰 받기: https://t.co/uCFgCx3vw1 이거해줘"
#         },
#         {
#             "author_id": "1347569064445558785",
#             "id": "1364142444099424260",
#             "text": "@4chan_24 먹는 모습 보면 그렇게 먹는다고 살이 찌겠어?! 하고 막 먹으라고 음식 같은거 다 앞으로 밀어놔주고 이거 먹어라 저거 먹어라 할 것 같아요 ㅋㅋㅋㅋㅋㅋㅋ"
# ...

# %%
bearer_token
# Out:
# 'AAAAAAAAAAAAAAAAAAAAAABHMwEAAAAA6FQjDcRr3NNzVzfLZN5MtYFiygQ%3DJQPCVWFEOBepCotJiUqBTLcvmGPONWMY4pOdwgs840QwwByVto'

# %%
import requests
import os
import json

# To set your environment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'


def auth():
    return os.environ.get("BEARER_TOKEN")


def create_url():
    # Replace with user ID below
    user_id = 1344918631361073154
    return "https://api.twitter.com/2/users/{}/tweets".format(user_id)


def get_params():
    # Tweet fields are adjustable.
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld
    return {"tweet.fields": "created_at"}


def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers


def connect_to_endpoint(url, headers, params):
    response = requests.request("GET", url, headers=headers, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()


def main():
    #bearer_token = auth()
    url = create_url()
    headers = create_headers(bearer_token)
    params = get_params()
    json_response = connect_to_endpoint(url, headers, params)
    print(json.dumps(json_response, indent=4, sort_keys=True,ensure_ascii=False))


if __name__ == "__main__":
    main()
# Out:
# 200
# {
#     "data": [
#         {
#             "created_at": "2021-02-23T08:36:47.000Z",
#             "id": "1364132081010241538",
#             "text": "@unsunghero123 일식집 인가요?\n음식이 맛나 보입니다만 \n\n뒤에 앉아계신분 슴가도 \n알흠다워보이시구요"
#         },
#         {
#             "created_at": "2021-02-23T08:27:51.000Z",
#             "id": "1364129833291145221",
#             "text": "공잘치시는분  \n주말에 초대 응해드리고 싶습니다 \n찐 80  초반 나와요"
#         },
#         {
#             "created_at": "2021-02-23T08:04:06.000Z",
#             "id": "1364123859025162243",
#             "text": "자기  본인  주장이 강한 사람은 \n설득하려 하지 말자  \n\n설득이나 이해를 시키려는  순간 \n내  자신만  더욱더  힘들뿐이다 \n\n그 기준선을 지키고자한다면  나를 먼저 설득시키려고 이해시키려고 노력하지마라 \n\n모는  기준은 내가 정하고  \n단지 너의 의견에서 조금 양보할뿐이다"
#         },
#         {
#             "created_at": "2021-02-23T06:38:21.000Z",
#             "id": "1364102278223826945",
#             "text": "@beauty99488522 ㅎㅎ  \n스타킹 지원해드리고 싶은데요"
#         },
#         {
#             "created_at": "2021-02-23T06:33:19.000Z",
# ...

# %%
os.listdir('/home/com/다운로드')
# Out:
# ['수원_정성_제안서_초안_20210215.pptx',
#  '수원-회의용-210215.pdf',
#  '과제.txt',
#  'saved-scripts-2021-02-04T12_13_18+0900.zip',
#  '보충자료-p8.pdf',
#  '공고문(수원시 빅데이터 기반 디지털옥외광고 구축 및 운영 용역).pdf',
#  '수원개요도.zip',
#  'download.tar.xz',
#  'elastic-book-snapshot-master',
#  'Anaconda3-2020.11-Linux-x86_64.sh',
#  'kibana-7.10.2-linux-x86_64',
#  '[참고자료]수원시 남문로데오거리 브랜드 콘텐츠 개발 용역 최종보고서.pdf',
#  '수원.pdf',
#  '수원 남문로데오거리 상권 활성화 접근방안.pptx',
#  'elasticsearch-7.10.2',
#  '박선정_포트폴리오_01023070764.pdf',
#  '경기도 수원시 가격동향_20210124.csv',
#  'CR ARTS XML PCM Technical Specification V3.00 20090429 (1).pdf',
#  '오늘.txt',
#  '수원시피피티.pptx',
#  'cuda-repo-ubuntu1804-10-1-local-10.1.105-418.39_1.0-1_amd64.deb',
#  'nsmc-master',
#  'neo4j-desktop-1.3.4-x86_64.AppImage',
#  'korlex1.0.zip',
#  'slack-knowledge-graph-master',
#  'mecab-0.996-ko-0.9.2',
#  'Neo4j Knowledge Sheet - resources.csv',
#  'CR ARTS XML PCM Domain Model V3.0.0 20090330.pdf',
#  'nlp-stanfordnlp-3.5.4.53.19-SNAPSHOT.jar',
# ...
